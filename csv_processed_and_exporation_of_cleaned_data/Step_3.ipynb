# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import seaborn as sns

# %%
sns.set_style ('whitegrid')

# %%
sns.set_context('notebook')

# %%
df=pd.read_csv('Life_expectancy_all.csv', index_col='State')

# %%
df.head(2)
# Out:
#          HSGradPer  BADegPer  AdvDegPer  LifeExp2018  LifeExp2010  \
# State
# Alabama       85.3      24.5        9.1         75.4         75.4
# Alaska        92.4      29.0       10.4         78.8         78.0
#
#          MaleLifeExp  FemLifeExp   PopTot  MurderNMTot  MurderTot  ...  \
# State                                                              ...
# Alabama         72.6        78.1  4853875          348        NaN  ...
# Alaska          76.7        81.2   737709           59       57.0  ...
#
#          Income2013  Income2012  Income2011  Income2010  Income2009  \
# State
# Alabama       42849       41574       41415       40474       40489
# Alaska        72237       67712       67825       64576       66953
#
#          Income2008  Income2007  Abb  Region            Division
# State
# Alabama       42666       40554   AL   South  East South Central
# Alaska        68460       64333   AK    West             Pacific
#
# [2 rows x 37 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, Alabama to Wyoming
# Data columns (total 37 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   HSGradPer      50 non-null     float64
#  1   BADegPer       50 non-null     float64
#  2   AdvDegPer      50 non-null     float64
#  3   LifeExp2018    50 non-null     float64
#  4   LifeExp2010    50 non-null     float64
#  5   MaleLifeExp    50 non-null     float64
#  6   FemLifeExp     50 non-null     float64
#  7   PopTot         50 non-null     int64
#  8   MurderNMTot    50 non-null     int64
#  9   MurderTot      48 non-null     float64
#  10  GunMurderTot   48 non-null     float64
#  11  GunOwnPer      50 non-null     float64
#  12  MurderNMRate   50 non-null     float64
#  13  MurderRate     48 non-null     float64
#  14  GunMurderRate  48 non-null     float64
#  15  TotalSqMi      50 non-null     float64
#  16  TotalKmQ       50 non-null     int64
# ...

# %%
df['Region']=pd.Categorical(df['Region'], ordered=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, Alabama to Wyoming
# Data columns (total 37 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   HSGradPer      50 non-null     float64
#  1   BADegPer       50 non-null     float64
#  2   AdvDegPer      50 non-null     float64
#  3   LifeExp2018    50 non-null     float64
#  4   LifeExp2010    50 non-null     float64
#  5   MaleLifeExp    50 non-null     float64
#  6   FemLifeExp     50 non-null     float64
#  7   PopTot         50 non-null     int64
#  8   MurderNMTot    50 non-null     int64
#  9   MurderTot      48 non-null     float64
#  10  GunMurderTot   48 non-null     float64
#  11  GunOwnPer      50 non-null     float64
#  12  MurderNMRate   50 non-null     float64
#  13  MurderRate     48 non-null     float64
#  14  GunMurderRate  48 non-null     float64
#  15  TotalSqMi      50 non-null     float64
#  16  TotalKmQ       50 non-null     int64
# ...

# %%
df['Division']=pd.Categorical(df['Division'], ordered=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, Alabama to Wyoming
# Data columns (total 37 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   HSGradPer      50 non-null     float64
#  1   BADegPer       50 non-null     float64
#  2   AdvDegPer      50 non-null     float64
#  3   LifeExp2018    50 non-null     float64
#  4   LifeExp2010    50 non-null     float64
#  5   MaleLifeExp    50 non-null     float64
#  6   FemLifeExp     50 non-null     float64
#  7   PopTot         50 non-null     int64
#  8   MurderNMTot    50 non-null     int64
#  9   MurderTot      48 non-null     float64
#  10  GunMurderTot   48 non-null     float64
#  11  GunOwnPer      50 non-null     float64
#  12  MurderNMRate   50 non-null     float64
#  13  MurderRate     48 non-null     float64
#  14  GunMurderRate  48 non-null     float64
#  15  TotalSqMi      50 non-null     float64
#  16  TotalKmQ       50 non-null     int64
# ...

# %%
df.head()
# Out:
#             HSGradPer  BADegPer  AdvDegPer  LifeExp2018  LifeExp2010  \
# State
# Alabama          85.3      24.5        9.1         75.4         75.4
# Alaska           92.4      29.0       10.4         78.8         78.0
# Arizona          82.1      28.4       10.7         79.9         79.3
# Arkansas         85.6      22.0        7.9         75.9         76.0
# California       82.5      32.6       12.2         81.6         80.6
#
#             MaleLifeExp  FemLifeExp    PopTot  MurderNMTot  MurderTot  ...  \
# State                                                                  ...
# Alabama            72.6        78.1   4853875          348        NaN  ...
# Alaska             76.7        81.2    737709           59       57.0  ...
# Arizona            77.5        82.3   6817565          306      278.0  ...
# Arkansas           73.1        78.6   2977853          181      164.0  ...
# California         79.4        83.8  38993940         1861     1861.0  ...
#
# ...

# %%
# Regression Plots

# %%
edu_cols=['HSGradPer', 'BADegPer','AdvDegPer']

# %%
edu_cols
# Out:
# ['HSGradPer', 'BADegPer', 'AdvDegPer']

# %%
edu_data=df.loc[:,['LifeExp2018','Region'] +  edu_cols]

# %%
edu_data
# Out:
#                 LifeExp2018         Region  HSGradPer  BADegPer  AdvDegPer
# State
# Alabama                75.4          South       85.3      24.5        9.1
# Alaska                 78.8           West       92.4      29.0       10.4
# Arizona                79.9           West       82.1      28.4       10.7
# Arkansas               75.9          South       85.6      22.0        7.9
# California             81.6           West       82.5      32.6       12.2
# Colorado               80.5           West       91.1      39.4       14.6
# Connecticut            80.9      Northeast       90.2      38.4       17.0
# Delaware               78.4          South       89.3      31.0       12.9
# Florida                80.0          South       87.6      28.5       10.3
# Georgia                77.8          South       86.3      29.9       11.4
# Hawaii                 82.3           West       91.6      32.0       10.8
# ...

# %%
edu_data_num=df.loc[:,['LifeExp2018']+edu_cols]

# %%
edu_data_num
# Out:
#                 LifeExp2018  HSGradPer  BADegPer  AdvDegPer
# State
# Alabama                75.4       85.3      24.5        9.1
# Alaska                 78.8       92.4      29.0       10.4
# Arizona                79.9       82.1      28.4       10.7
# Arkansas               75.9       85.6      22.0        7.9
# California             81.6       82.5      32.6       12.2
# Colorado               80.5       91.1      39.4       14.6
# Connecticut            80.9       90.2      38.4       17.0
# Delaware               78.4       89.3      31.0       12.9
# Florida                80.0       87.6      28.5       10.3
# Georgia                77.8       86.3      29.9       11.4
# Hawaii                 82.3       91.6      32.0       10.8
# Idaho                  79.3       90.2      26.8        8.5
# Illinois               79.3       88.6      33.4       13.0
# Indiana                77.0       88.3      25.3        9.2
# Iowa                   79.4       91.8      27.7        9.0
# ...

# %%
# compute the correlation matrix
corr_matrix_edu=edu_data_num.corr()

# %%
corr_matrix_edu
# Out:
#              LifeExp2018  HSGradPer  BADegPer  AdvDegPer
# LifeExp2018     1.000000   0.319468  0.764808   0.557600
# HSGradPer       0.319468   1.000000  0.355112   0.166278
# BADegPer        0.764808   0.355112  1.000000   0.912680
# AdvDegPer       0.557600   0.166278  0.912680   1.000000

# %%
# heatmap showing the correlation of the edu variables and life expectancy

# %%
fig, ax0=plt.subplots()
sns.heatmap(corr_matrix_edu, annot=True, cmap='YlGnBu', ax=ax0)
#margin bigs
#b, t= plt.ylim ()
# plt.ylim(b+0.5, t-.5)
plt.yticks(rotation=45)
ax0.set_title('correlation of Education variables and Life Expectancy')
plt.savefig('heatmap_edu.png')
plt.show()

# %%
# Regression plots for the education variables

# %%
Corr_HSGradper=corr_matrix_edu.loc['LifeExp2018', 'HSGradPer']
Corr_BADegPer=corr_matrix_edu.loc['LifeExp2018', 'BADegPer']
Corr_AdvDegPer=corr_matrix_edu.loc['LifeExp2018', 'AdvDegPer']

# %%
Corr_HSGradper
# Out:
# 0.3194681281712101

# %%
Corr_BADegPer
# Out:
# 0.5576003712893742

# %%
Corr_AdvDegPer
# Out:
# 0.5576003712893742

# %%
fig, (ax1, ax2, ax3)=plt.subplots(nrows=1,ncols=3, sharey=True, figsize=(17,4))
#High school Degree
s1=sns.regplot(x='HSGradPer', y='LifeExp2018', color='Purple', data=df, ax=ax1)
s1.set(title='Corr: {:.4f}'.format(Corr_HSGradper), xlabel='Highschool Graduates (%)', ylabel='Life Expectancy')

#Bachelor Degree
s2=sns.regplot(x='BADegPer', y='LifeExp2018', color='Purple', data=df, ax=ax2)
s2.set(title='Corr: {:.4f}'.format(Corr_BADegPer), xlabel='Bachelor Degree Graduates (%)', ylabel='')

# Advanced degree
s3=sns.regplot(x='AdvDegPer', y='LifeExp2018', color='Purple', data=df, ax=ax3)
s3.set(title='Corr: {:.4f}'.format(Corr_AdvDegPer), xlabel='Advanced Degree Graduates (%)', ylabel='')

fig.suptitle ('Life Expectancy per state (2018)')
plt.savefig('regplots_edu.png')
plt.show()

# %%
# Crime variable
murder_cols=['MurderNMTot', 'MurderTot','GunMurderTot','GunOwnPer','MurderNMRate','MurderRate','GunMurderRate']

# %%
murder_data=df.loc[:,['LifeExp2018', 'Region']+ murder_cols]

# %%
murder_data
# Out:
#                 LifeExp2018         Region  MurderNMTot  MurderTot  \
# State
# Alabama                75.4          South          348        NaN
# Alaska                 78.8           West           59       57.0
# Arizona                79.9           West          306      278.0
# Arkansas               75.9          South          181      164.0
# California             81.6           West         1861     1861.0
# Colorado               80.5           West          176      176.0
# Connecticut            80.9      Northeast          117      107.0
# Delaware               78.4          South           63       63.0
# Florida                80.0          South         1041        NaN
# Georgia                77.8          South          615      565.0
# Hawaii                 82.3           West           19       19.0
# Idaho                  79.3           West           32       30.0
# Illinois               79.3  North Central          744      497.0
# ...

# %%
murder_data_num=df.loc[:,['LifeExp2018']+murder_cols]

# %%
murder_data_num
# Out:
#                 LifeExp2018  MurderNMTot  MurderTot  GunMurderTot  GunOwnPer  \
# State
# Alabama                75.4          348        NaN           NaN       48.9
# Alaska                 78.8           59       57.0          39.0       61.7
# Arizona                79.9          306      278.0         171.0       32.3
# Arkansas               75.9          181      164.0         110.0       57.9
# California             81.6         1861     1861.0        1275.0       20.1
# Colorado               80.5          176      176.0         115.0       34.3
# Connecticut            80.9          117      107.0          73.0       16.6
# Delaware               78.4           63       63.0          52.0        5.2
# Florida                80.0         1041        NaN           NaN       32.5
# Georgia                77.8          615      565.0         464.0       31.6
# Hawaii                 82.3           19       19.0           4.0       45.1
# ...

# %%
corr_matrix_murder=murder_data_num.corr()

# %%
corr_matrix_murder
# Out:
#                LifeExp2018  MurderNMTot  MurderTot  GunMurderTot  GunOwnPer  \
# LifeExp2018       1.000000     0.054852   0.050802      0.018779  -0.400586
# MurderNMTot       0.054852     1.000000   0.991947      0.993682  -0.205636
# MurderTot         0.050802     0.991947   1.000000      0.994767  -0.218265
# GunMurderTot      0.018779     0.993682   0.994767      1.000000  -0.210238
# GunOwnPer        -0.400586    -0.205636  -0.218265     -0.210238   1.000000
# MurderNMRate     -0.611605     0.346355   0.318341      0.363434   0.192487
# MurderRate       -0.555899     0.365836   0.361828      0.400710   0.148581
# GunMurderRate    -0.538607     0.382399   0.369871      0.421208   0.095052
#
#                MurderNMRate  MurderRate  GunMurderRate
# LifeExp2018       -0.611605   -0.555899      -0.538607
# MurderNMTot        0.346355    0.365836       0.382399
# MurderTot          0.318341    0.361828       0.369871
# GunMurderTot       0.363434    0.400710       0.421208
# ...

# %%
fig, ax0=plt.subplots()
sns.heatmap(corr_matrix_murder, annot=True, cmap='YlGnBu', ax=ax0)
# margin bugs
#b, t=plt.ylim()
#plt.ylim(b+0.5, t-.5)
plt.yticks(rotation=45)
ax0.set_title('Correlation of Murder Variables and Life Expectancy')
plt.savefig('heatmap_murder.png')
plt.show()

# %%
corr_MurderNMTot=corr_matrix_murder.loc['LifeExp2018','MurderNMTot']
corr_GunMurder=corr_matrix_murder.loc['LifeExp2018','GunMurderTot']
corr_MurderTot=corr_matrix_murder.loc['LifeExp2018','MurderTot']

# %%
fig, (ax1, ax2, ax3)=plt.subplots(nrows=1,ncols=3,sharey=True,figsize=(17,4))
# Murder and non-negligent Manslaughte
s1=sns.regplot(x='MurderNMTot', y='LifeExp2018', data=df, ax=ax1)
s1.set(title='Corr: {:.4f}'.format(corr_MurderNMTot), xlabel='Murder and non-negligent Manslaughter (total deaths)', ylabel='Life Expectancy')

# Gun Murder 
s2=sns.regplot(x='GunMurderTot', y='LifeExp2018', data=df, ax=ax2)
s2.set(title='Corr: {:.4f}'.format(corr_GunMurder), xlabel='Gun Murder (total deaths)', ylabel='')

# Murders
s3=sns.regplot(x='MurderTot', y='LifeExp2018', data=df, ax=ax3)
s3.set(title='Corr: {:.4f}'.format(corr_MurderTot), xlabel='Murders (total deaths)', ylabel='')

fig.suptitle('Life Expectancy per state (2018)')
plt.savefig('regplots_crime.png')
plt.show()

# %%
# Regression plot for gun ownership

# %%
corr_GunOwnPer=corr_matrix_murder.loc['LifeExp2018', 'GunOwnPer']
s4=sns.regplot(x='GunOwnPer',y='LifeExp2018', data=df, color='red')
s4.set_title('Life Expectancy per State (2018) \n Corr: {:.4f}'.format(corr_GunOwnPer))
s4.set(xlabel = 'Gun Owner (%)', ylabel='Life Expectancy (years)')
plt.savefig ('LifeExp2018_regplot_gun_owner.png')
plt.show ()

# %%
# Regression plots for murder (rates)

# %%
corr_MurderNMRate=corr_matrix_murder.loc['LifeExp2018', 'MurderNMRate']
corr_GunMurderRate=corr_matrix_murder.loc['LifeExp2018', 'GunMurderRate']
corr_MurderRate=corr_matrix_murder.loc['LifeExp2018', 'MurderRate']

# %%
fig, (ax1,ax2,ax3)=plt.subplots(nrows=1,ncols=3, sharey=True, figsize=(17,4))

# Non-Negligent mansalughter Murder rate
s1=sns.regplot(x='MurderNMRate', y='LifeExp2018', data=df, ax=ax1)
s1.set(title='Corr: {:.4f}'.format(corr_MurderNMRate), xlabel='Murder and non-negligent manslaughter (rate)', ylabel='Life Expectancy')

# Gun Murder rate
s2=sns.regplot(x='GunMurderRate', y='LifeExp2018', data=df, ax=ax2)
s2.set(title='Corr: {:.4f}'.format(corr_GunMurderRate), xlabel='Gun Murder (rate)', ylabel='')

# Murder total

s3=sns.regplot(x='MurderRate', y='LifeExp2018', data=df, ax=ax3)
s3.set(title='Corr: {:.4f}'.format(corr_MurderRate), xlabel='Murders (rate)', ylabel='')

fig.suptitle('Life Expectancy per state (2018)')
plt.savefig('regplots_Murder_rates_crime.png')
plt.show ()

# %%
# ECDF for murder (totals)

x1=np.sort(df['MurderNMTot'])
x2=np.sort(df['GunMurderTot'])
x3=np.sort(df['MurderTot'])
y=np.arange(1, len(x1)+1)/len(x1)
fig, ax=plt.subplots ()
ax.plot(x1,y,'.',linestyle='none',color='blue',label='Murder NM')
ax.plot(x2,y,'.',linestyle='none',color='green',label='Gun Murder')
ax.plot(x3,y,'.',linestyle='none',color='red',label='Murder')

ax.set_xlabel('Murder (tot)')
ax.set_ylabel('ECDF')
ax.set_title('Empirical Cummulative Distribution \n of total murders')
ax.legend()
plt.margins(0.02)
plt.savefig('ecdf_murder.png')
plt.show ()

# %%
 # ECDF for murder rates
x1=np.sort(df['MurderNMRate'])
x2=np.sort(df['GunMurderRate'])
x3=np.sort(df['MurderRate'])
y=np.arange(1, len(x1)+1)/len(x1)
fig, ax=plt.subplots ()
ax.plot(x1,y,'.',linestyle='none',color='blue',label='Murder NM')
ax.plot(x2,y,'.',linestyle='none',color='green',label='Gun Murder')
ax.plot(x3,y,'.',linestyle='none',color='red',label='Murder')

ax.set_xlabel('Murder (tot)')
ax.set_ylabel('ECDF')
ax.set_title('Empirical Cummulative Distribution \n of murders rates')
ax.legend()
plt.margins(0.02)
plt.savefig('ecdf_murder_rates.png')
plt.show ()

# %%
# Area variables

# %%
df.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, Alabama to Wyoming
# Data columns (total 37 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   HSGradPer      50 non-null     float64
#  1   BADegPer       50 non-null     float64
#  2   AdvDegPer      50 non-null     float64
#  3   LifeExp2018    50 non-null     float64
#  4   LifeExp2010    50 non-null     float64
#  5   MaleLifeExp    50 non-null     float64
#  6   FemLifeExp     50 non-null     float64
#  7   PopTot         50 non-null     int64
#  8   MurderNMTot    50 non-null     int64
#  9   MurderTot      48 non-null     float64
#  10  GunMurderTot   48 non-null     float64
#  11  GunOwnPer      50 non-null     float64
#  12  MurderNMRate   50 non-null     float64
#  13  MurderRate     48 non-null     float64
#  14  GunMurderRate  48 non-null     float64
#  15  TotalSqMi      50 non-null     float64
#  16  TotalKmQ       50 non-null     int64
# ...

# %%
area_cols=['TotalKmQ', 'LandKmQ', 'WaterKmQ']

# %%
area_data=df.loc[:,['LifeExp2018','Region']+ area_cols]

# %%
area_data_num=df.loc[:,['LifeExp2018']+ area_cols]

# %%
corr_matrix_area=area_data_num.corr()

# %%
corr_matrix_area
# Out:
#              LifeExp2018  TotalKmQ   LandKmQ  WaterKmQ
# LifeExp2018     1.000000  0.061225  0.062685  0.040650
# TotalKmQ        0.061225  1.000000  0.995767  0.832981
# LandKmQ         0.062685  0.995767  1.000000  0.778597
# WaterKmQ        0.040650  0.832981  0.778597  1.000000

# %%
# heatmap

# %%
fig, ax0=plt.subplots()
sns.heatmap(corr_matrix_area, annot=True, cmap='YlGnBu', ax=ax0)
# margin bugs
#b, t=plt.ylim()
#plt.ylim(b+0.5, t-.5)
plt.yticks(rotation=45)
ax0.set_title('Heatmap of Area Variables and Life Expectancy')
plt.savefig('heatmap_area.png')
plt.show()

# %%
# Regression plots for area variables

# %%
corr_TotalKmQ=corr_matrix_area.loc['LifeExp2018','TotalKmQ']
corr_LandKmQ=corr_matrix_area.loc['LifeExp2018','LandKmQ']
corr_WaterKmQ=corr_matrix_area.loc['LifeExp2018','WaterKmQ']

# %%
fig, (ax1, ax2,ax3)=plt.subplots(nrows=1,ncols=3, sharey=True,figsize=(17,4))
sns.regplot(x='TotalKmQ', y='LifeExp2018', data=df,ax=ax1)
ax1.set(title='Corr: {:.4f}'.format(corr_TotalKmQ), xlabel='Total area (KmQ)', ylabel='Life Expectancy (year)')
plt.setp(ax1.get_xticklabels(), rotation=45)
# land area 
sns.regplot(x='LandKmQ', y='LifeExp2018', data=df,ax=ax2)
ax2.set(title='Corr: {:.4f}'.format(corr_LandKmQ), xlabel='land area  (KmQ)', ylabel='')
plt.setp(ax2.get_xticklabels(), rotation=45)
# Water 
sns.regplot(x='WaterKmQ', y='LifeExp2018', data=df,ax=ax3)
ax3.set(title='Corr: {:.4f}'.format(corr_WaterKmQ), xlabel='Water Area(KmQ)', ylabel='')
plt.setp(ax3.get_xticklabels(), rotation=45)
fig.suptitle('Life Expectancy per state (2018)')
plt.savefig('regplots_area.png')
plt.show()
